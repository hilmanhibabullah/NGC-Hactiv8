# %% [markdown]
# Nama saya adalah Hilman Hibabullah. Dalam project ini saya mengolah data pokemon dari sumber https://www.kaggle.com/abcsds/pokemon dengan menggunakan pandas. Saya ingin melihat apakah ada perkembangan data pokemon dari pokemon generasi 1 sampai 6

# %% [markdown]
# mengimport pandas

# %%
import pandas as pd

# %% [markdown]
# mengambil file excel dan membacanya sebagai data csv

# %%
pokemon = pd.read_csv("Pokemon.csv")

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# melihat data teratas dari file pokemon

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# melihat data paling bawah dari file pokemon

# %%
pokemon.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# mengambil sampel acak dari file pokemon

# %%
pokemon.sample()
# Out:
#        #        Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 650  589  Escavalier    Bug  Steel    495  70     135      105       60
#
#      Sp. Def  Speed  Generation  Legendary
# 650      105     20           5      False

# %% [markdown]
# melihat isi dari file(nama columns, total data tiap column, jenis data di column, total colomn dll)

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# melihat isi dari colomn Type 1, dan masing masing data yang ada di Type1

# %%
pokemon["Type 1"].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
#            ...
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, Length: 18, dtype: int64

# %% [markdown]
# melihat isi dari colomn Type 1, dan masing masing data yang ada di Type2

# %%
pokemon["Type 2"].value_counts()
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
#             ..
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, Length: 18, dtype: int64

# %% [markdown]
# Mengganti nama Colomns #, Type 1, Type 2, Total, Sp. Atk, Sp. Def menjadi Number,Type1,Type2,Total Power,Special Attack,Special Deffense. Serta mengganti data frame pokemon menjadi pokemon_new

# %%
pokemon_new = pokemon.rename(columns={"#":"Number","Type 1":"Type1", "Type 2":"Type2", "Total":"Total Power","Sp. Atk":"Special Attack", "Sp. Def":"Special Deffense"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ec25313ec645> in <module>
# ----> 1 pokemon_new = pokemon.rename(columns={"#":"Number","Type 1":"Type1", "Type 2":"Type2", "Total":"Total Power","Sp. Atk":"Special Attack", "Sp. Def":"Special Deffense"})
#
# NameError: name 'pokemon' is not defined

# %% [markdown]
# Melihat data teratas setelah mengganti beberapa nama colomn

# %%
pokemon_new.head()
# Out:
#    Number                   Name  Type1   Type2  Total Power  HP  Attack  \
# 0       1              Bulbasaur  Grass  Poison          318  45      49
# 1       2                Ivysaur  Grass  Poison          405  60      62
# 2       3               Venusaur  Grass  Poison          525  80      82
# 3       3  VenusaurMega Venusaur  Grass  Poison          625  80     100
# 4       4             Charmander   Fire     NaN          309  39      52
#
#    Defense  Special Attack  Special Deffense  Speed  Generation  Legendary
# 0       49              65                65     45           1      False
# 1       63              80                80     60           1      False
# 2       83             100               100     80           1      False
# 3      123             122               120     80           1      False
# 4       43              60                50     65           1      False

# %% [markdown]
# Mencari modus di colomn Type2

# %%
pokemon_new.Type2.mode()
# Out:
# 0    Flying
# dtype: object

# %% [markdown]
# Mengisi data yang kosong di colomn Type2 dengan Flying, karena Flying adalah modus di colomn Type2

# %%
pokemon_new.Type2.fillna("Flying")
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4      Flying
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type2, Length: 800, dtype: object

# %% [markdown]
# Mengisi colomn Type2 dengan fungsi yang mengisi data yang kosong di colomn Type2

# %%
pokemon_new.Type2 = pokemon_new.Type2.fillna("Flying")

# %% [markdown]
# Melihat isi data pokemon_new yang baru setelah data yang kosong di colomn Type2 terisi semua

# %%
pokemon_new
# Out:
#      Number                   Name    Type1   Type2  Total Power  HP  Attack  \
# 0         1              Bulbasaur    Grass  Poison          318  45      49
# 1         2                Ivysaur    Grass  Poison          405  60      62
# 2         3               Venusaur    Grass  Poison          525  80      82
# 3         3  VenusaurMega Venusaur    Grass  Poison          625  80     100
# 4         4             Charmander     Fire  Flying          309  39      52
# ..      ...                    ...      ...     ...          ...  ..     ...
# 795     719                Diancie     Rock   Fairy          600  50     100
# 796     719    DiancieMega Diancie     Rock   Fairy          700  50     160
# 797     720    HoopaHoopa Confined  Psychic   Ghost          600  80     110
# 798     720     HoopaHoopa Unbound  Psychic    Dark          680  80     160
# 799     721              Volcanion     Fire   Water          600  80     110
#
# ...

# %% [markdown]
# Mengecek seluruh data pokemon_new untuk memastikan sudah tidak ada lagi data yang kosong

# %%
pokemon_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Number            800 non-null    int64
#  1   Name              800 non-null    object
#  2   Type1             800 non-null    object
#  3   Type2             800 non-null    object
#  4   Total Power       800 non-null    int64
#  5   HP                800 non-null    int64
#  6   Attack            800 non-null    int64
#  7   Defense           800 non-null    int64
#  8   Special Attack    800 non-null    int64
#  9   Special Deffense  800 non-null    int64
#  10  Speed             800 non-null    int64
#  11  Generation        800 non-null    int64
#  12  Legendary         800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# Melihat isi dan banyakanya colomn Generation

# %%
pokemon_new["Generation"].value_counts()
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %% [markdown]
# Melihat isi dan banyakanya colomn Total Power

# %%
pokemon_new["Total Power"].value_counts()
# Out:
# 600    37
# 405    26
# 580    23
# 500    23
# 300    19
#        ..
# 351     1
# 352     1
# 473     1
# 358     1
# 180     1
# Name: Total Power, Length: 200, dtype: int64

# %% [markdown]
# Mengquery colomn Generation, Total Power, Special Attack, Special Deffense dengan syarat Hanya ada data Generation yang ke 6 yang memiliki total power diatas 500, special attack diatas 100, special deffense diatas 100

# %%
pokemon_new[
    (pokemon_new["Generation"] == 6) &
    (pokemon_new["Total Power"] > 500 ) &
    (pokemon_new["Special Attack"] > 100) &
    (pokemon_new["Special Deffense"] > 100)
]
# Out:
#      Number                 Name    Type1   Type2  Total Power  HP  Attack  \
# 739     671              Florges    Fairy  Flying          552  78      65
# 770     700              Sylveon    Fairy  Flying          525  95      65
# 776     706               Goodra   Dragon  Flying          600  90     100
# 796     719  DiancieMega Diancie     Rock   Fairy          700  50     160
# 797     720  HoopaHoopa Confined  Psychic   Ghost          600  80     110
# 798     720   HoopaHoopa Unbound  Psychic    Dark          680  80     160
#
#      Defense  Special Attack  Special Deffense  Speed  Generation  Legendary
# 739       68             112               154     75           6      False
# 770       65             110               130     60           6      False
# 776       70             110               150     80           6      False
# 796      110             160               110    110           6       True
# ...

# %% [markdown]
# Mengquery colomn Generation, Total Power, Special Attack, Special Deffense dengan syarat Hanya ada data Generation yang ke 1 yang memiliki total power diatas 500, special attack diatas 100, special deffense diatas 100

# %%
pokemon_new[
    (pokemon_new["Generation"] == 1) &
    (pokemon_new["Total Power"] > 500 ) &
    (pokemon_new["Special Attack"] > 100) &
    (pokemon_new["Special Deffense"] > 100)
]
# Out:
#      Number                       Name    Type1   Type2  Total Power   HP  \
# 3         3      VenusaurMega Venusaur    Grass  Poison          625   80
# 8         6  CharizardMega Charizard Y     Fire  Flying          634   78
# 12        9    BlastoiseMega Blastoise    Water  Flying          630   79
# 164     150        MewtwoMega Mewtwo Y  Psychic  Flying          780  106
#
#      Attack  Defense  Special Attack  Special Deffense  Speed  Generation  \
# 3       100      123             122               120     80           1
# 8       104       78             159               115    100           1
# 12      103      120             135               115     78           1
# 164     150       70             194               120    140           1
#
#      Legendary
# 3        False
# 8        False
# 12       False
# 164       True

# %% [markdown]
# Mengquery colomn Generation, Total Power, Special Attack, Special Deffense dengan syarat generasi yang lebih dari 0 yang memiliki total power diatas 500, special attack diatas 100, special deffense diatas 100

# %%
pokemon_new[
(pokemon_new["Generation"] > 0) & 
    (pokemon_new["Total Power"] > 500 ) &
    (pokemon_new["Special Attack"] > 100) &
    (pokemon_new["Special Deffense"] > 100)]
# Out:
#      Number                       Name     Type1   Type2  Total Power   HP  \
# 3         3      VenusaurMega Venusaur     Grass  Poison          625   80
# 8         6  CharizardMega Charizard Y      Fire  Flying          634   78
# 12        9    BlastoiseMega Blastoise     Water  Flying          630   79
# 164     150        MewtwoMega Mewtwo Y   Psychic  Flying          780  106
# 196     181      AmpharosMega Ampharos  Electric  Dragon          610   90
# ..      ...                        ...       ...     ...          ...  ...
# 770     700                    Sylveon     Fairy  Flying          525   95
# 776     706                     Goodra    Dragon  Flying          600   90
# 796     719        DiancieMega Diancie      Rock   Fairy          700   50
# 797     720        HoopaHoopa Confined   Psychic   Ghost          600   80
# 798     720         HoopaHoopa Unbound   Psychic    Dark          680   80
#
# ...

# %% [markdown]
# Mengelompokkan colomn Generation dan colomn Type1 dengan menghitung jumlah dari setiap masing masing Generation (1,2,3,4,5,6)

# %%
pokemon_new.groupby("Generation", sort=False)["Type1"].count()
# Out:
# Generation
# 1    166
# 2    106
# 3    160
# 4    121
# 5    165
# 6     82
# Name: Type1, dtype: int64

# %% [markdown]
# Mengquery colomn Generation dan Total Power dengan syarat generasi 6 yang memiliki total power diatas atau sama dengan 400, lalu melihat dengan mengelompokkan Type1,Type2 dengan angka Total Power yang paling besar

# %%
pokemon_new[
    (pokemon_new["Generation"] == 6) &
    (pokemon_new["Total Power"] >= 400 )
].groupby(["Type1", "Type2"])["Total Power"].max()
# Out:
# Type1   Type2
# Bug     Flying     411
# Dark    Flying     680
#         Psychic    482
# Dragon  Flying     600
#         Ground     600
#                   ...
# Rock    Water      500
# Steel   Fairy      470
#         Ghost      520
# Water   Dark       530
#         Flying     500
# Name: Total Power, Length: 33, dtype: int64

# %% [markdown]
# Mengquery colomn Generation dan Total Power dengan syarat generasi 1 yang memiliki total power diatas atau sama dengan 400, lalu melihat dengan mengelompokkan Type1,Type2 dengan angka Total Power yang paling besar

# %%
pokemon_new[
    (pokemon_new["Generation"] == 1) &
    (pokemon_new["Total Power"] >= 400 )
].groupby(["Type1", "Type2"])["Total Power"].max()
# Out:
# Type1     Type2
# Bug       Flying      600
#           Grass       405
#           Poison      495
# Dragon    Flying      600
# Electric  Flying      580
#                      ...
# Water     Fighting    510
#           Flying      630
#           Ice         535
#           Poison      515
#           Psychic     590
# Name: Total Power, Length: 34, dtype: int64

# %% [markdown]
# Membuat plot bar data Generation dengan tujuan ingin melihat dan menghitung banyaknya pokemon yang di buat tiap generasi

# %%
pokemon_new["Generation"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Membuat plot dengan tujuan untuk melihat apa saja pokemon generasi 1 yang dibuat dan melihat nilai total power yang paling tinggi

# %%
pokemon_new[pokemon_new["Generation"] == 1].groupby("Type1")["Total Power"].max().plot()
# Out:
# <AxesSubplot:xlabel='Type1'>

# %% [markdown]
# Membuat plot dengan tujuan untuk melihat apa saja pokemon generasi 6 yang dibuat dan melihat nilai total power yang paling tinggi

# %%
pokemon_new[pokemon_new["Generation"] == 6].groupby("Type1")["Total Power"].max().plot()
# Out:
# <AxesSubplot:xlabel='Type1'>

# %% [markdown]
# Kesimpulan dari data yang saya buat adalah dalam data pokemon terdapat beberapa pokemon dengan berbagai type dari generasi 1 sampai generasi 6. saya membandingkan pokemon yang di buat dari generasi 1 dan generasi 6 dan mendapatkan bahwa dalam generasi 1 pokemon yang dibuat hanya pokemon type bug, electric, fighting, ghost, ground, normal, psychic, water dengan rata rata total power maksimal diatas 500. Sedangkan pada generasi 6 ada perkembangan type pokemon baru yaitu pokemon type dragon, fairy, fire, ice, poison, rock dengan rata rata total power maksimal diatas 450, namun beberapa type di generasi 6 diciptakan dengan total power yang tinggi diatas 550, hal ini bisa di lihat dengan melihat plot generasi 1 dan plot generasi 6 di akhir data.
#
# Dengan hal tersebut saya memiliki kesimpulan bahwa adanya perkembangan dan penambahan jenis pokemon dari generasi 1 hingga generasi 6, serta dalam generasi 6 terlihat developer lebih banyak menciptakan pokemon baru dengan total power yang lebih tinggi dibandingan pokemon generasi 1
